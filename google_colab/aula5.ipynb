# %% [markdown]
# exercícios: Tabuada

# %%
x1 = (input("digite o numero cujo deseja saber a tabuada:"))
x = x1
tabuada == x * 10
while (x >= tabuada):
    print(x)
    x = x + x1
# Out:
# digite o numero cujo deseja saber a tabuada:6

# %%
nr = 5
x = 1
while x <= 10:
  if x <= 10:
    print(f"{nr} x {x} = {nr * x}")
    x += 1
  else:
    break
# Out:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
nr = int(input("Digite o número para ver a tabuada: "))

print(f"Tabuada do {nr}:")
for i in range(1, 11): # Loop de 1 a 10 para a tabuada
  print(f"{nr} x {i} = {nr * i}")
# Out:
# Digite o número para ver a tabuada: 1
# Tabuada do 1:
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
# 1 x 10 = 10

# %%
nr = int(input("De qual número deseja calcular a tabuada?"))
x = 1
while x <= 10:
  calculo = x * nr
  print(f'{nr} * {x:2} = {calculo}')
  x = x + 1
# Out:
# De qual número deseja calcular a tabuada?6
# 6 *  1 = 6
# 6 *  2 = 12
# 6 *  3 = 18
# 6 *  4 = 24
# 6 *  5 = 30
# 6 *  6 = 36
# 6 *  7 = 42
# 6 *  8 = 48
# 6 *  9 = 54
# 6 * 10 = 60

# %% [markdown]
# t = int(input("De qual número deseja calcular a tabuada?: "))
# while:
#   n = 1
#   print (f"Tabuada de {t}:")
#   print (f"="*15)
#   while n <= 10:
#     print(f"{t} x {n} = {t * n}")
#     n += 1
#   t += 1

# %%
t = 1
while t <= 10:
  t = int(input("(digite 11 para encerrar) De qual número deseja calcular a tabuada entre 1 e 10?: "))
  if (t == 11):
    print('programa finalizado.')
    break
  n = 1
  print (f"Tabuada de {t}:")
  print (f"="*15)
  while n <= 10:
    print(f"{t} x {n} = {t * n}")
    n += 1
  t += 1

# %%
n = 1
n1 = 1
n2 = 1
while True:
  n = int(input('digite (1) para adição, (2) para diminuição, (3) para multiplicação ou (4) para divisão. (digite 5 para encerrar): '))
  if n == 5:
    print('sistema encerrado.')
    break
  n1 = int(input('digite o primeiro número: '))
  n2 = int(input('digite o segundo número: '))
  print( )
  if n == 1:
    print(f'{n1} + {n2} = {n1 + n2}')
  elif n == 2:
    print(f'{n1} - {n2} = {n1 - n2}')
  elif n == 3:
    print(f'{n1} x {n2} = {n1 * n2}')
  elif n == 4:
    print(f'{n1} / {n2} = {n1 / n2}')
  else:
    print('operação invalida, selecione uma operação valida.')
  print( )
# Out:
# digite (1) para adição, (2) para diminuição, (3) para multiplicação ou (4) para divisão. (digite 5 para encerrar): 7
# digite o primeiro número: 6
# digite o segundo número: 6
#
# operação invalida, selecione uma operação valida.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_75386/2221794655.py in <cell line: 0>()
#       3 n2 = 1
#       4 while True:
# ----> 5   n = int(input('digite (1) para adição, (2) para diminuição, (3) para multiplicação ou (4) para divisão. (digite 5 para encerrar): '))
#       6   if n == 5:
#       7     print('sistema encerrado.')
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
# ...

# %%
t = 1
while t <= 10:
  t = int(input("(digite 11 para encerrar) De qual número deseja calcular a tabuada entre 1 e 10?: "))
  if (t == 11):
    print( )
    print('programa finalizado.')
    break
  print( )
  oper = input('digite a operação(+, -, *, /): ')
  n = 1
  print( )
  print (f"Tabuada de {t}: ")
  print (f"="*15)
  while n <= 10:
    print( )
    if (oper == '+'):
      print(f"{t} + {n} = {t + n}")
    elif (oper == '-'):
      print(f"{t} - {n} = {t - n}")
    elif (oper == '*'):
      print(f"{t} * {n} = {t * n}")
    elif (oper == '/'):
      print(f"{t} / {n} = {t / n}")
    else:
      print('operação invalida!')
      break
    n += 1
# Out:
# Tabuada de 5:
# ...
#
# 5 * 1 = 5
#
# 5 * 2 = 10
#
# 5 * 3 = 15
#
# 5 * 4 = 20
#
# 5 * 5 = 25
#
# 5 * 6 = 30
#
# 5 * 7 = 35
#
# 5 * 8 = 40
#
# 5 * 9 = 45
#
# 5 * 10 = 50
